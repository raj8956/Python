# %%
#import libraries for data manipulation
import numpy as np
import pandas as pd

#import libraries for data visualization
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing the dataset

# %%
# read the data
df = pd.read_csv('C:\\Users\\19195\\Desktop\\DataAnalytics\\GreatLearning\\austo_automobile.csv')
# returns the first 5 rows
df.head()
# Out:
#    Age Gender Profession Marital_status      Education  No_of_Dependents  \
# 0   24   Male   Salaried        Married  Post Graduate                 4
# 1   28   Male   Salaried        Married  Post Graduate                 3
# 2   23   Male   Salaried        Married       Graduate                 4
# 3   26   Male   Business        Married  Post Graduate                 4
# 4   28   Male   Business        Married  Post Graduate                 4
#
#   Personal_loan House_loan Partner_working  Salary  Partner_salary  \
# 0            No        Yes             Yes   52000           25000
# 1            No        Yes              No   68000               0
# 2           Yes        Yes              No   31000               0
# 3           Yes        Yes             Yes   66000           35000
# 4           Yes         No              No   64000               0
#
#    Total_salary  Price       Make
# 0         77000  18000  Hatchback
# 1         68000  18000  Hatchback
# ...

# %% [markdown]
# # Data Overview

# %% [markdown]
# 1: How many rows and columns are present in the data?

# %%
# Check the shape of the dataset\
df.shape
# Out:
# (1581, 14)

# %% [markdown]
# 2: What are the datatypes of the different columns in the dataset?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1581 entries, 0 to 1580
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1581 non-null   int64
#  1   Gender            1581 non-null   object
#  2   Profession        1581 non-null   object
#  3   Marital_status    1581 non-null   object
#  4   Education         1581 non-null   object
#  5   No_of_Dependents  1581 non-null   int64
#  6   Personal_loan     1581 non-null   object
#  7   House_loan        1581 non-null   object
#  8   Partner_working   1581 non-null   object
#  9   Salary            1581 non-null   int64
#  10  Partner_salary    1581 non-null   int64
#  11  Total_salary      1581 non-null   int64
#  12  Price             1581 non-null   int64
#  13  Make              1581 non-null   object
# dtypes: int64(6), object(8)
# memory usage: 173.0+ KB

# %% [markdown]
# 3: Check the statistical summary of the data. What is the minimu, avergae, and maximum Price of the cars?

# %%
df.describe()  #finds the statistical summary of all the columns
df["Price"].mean()  #finds Average 
df["Price"].min()
df["Price"].max()
# Out:
# 70000

# %% [markdown]
# 4: Are there any missing values in the data? If yes, treat them using an appropriate method.

# %%
df.dropna(axis=1, inplace=True)
df
# Out:
#       Age Gender Profession Marital_status      Education  No_of_Dependents  \
# 0      24   Male   Salaried        Married  Post Graduate                 4
# 1      28   Male   Salaried        Married  Post Graduate                 3
# 2      23   Male   Salaried        Married       Graduate                 4
# 3      26   Male   Business        Married  Post Graduate                 4
# 4      28   Male   Business        Married  Post Graduate                 4
# ...   ...    ...        ...            ...            ...               ...
# 1576   28   Male   Salaried        Married  Post Graduate                 2
# 1577   23   Male   Salaried         Single       Graduate                 2
# 1578   23   Male   Business        Married       Graduate                 4
# 1579   25   Male   Business        Married  Post Graduate                 3
# 1580   28   Male   Salaried        Married       Graduate                 4
#
# ...

# %% [markdown]
# 5: How many cars are there of type SUV?

# %%
df1 = df[df.Make == "SUV"]
df1.value_counts('Make')
# Out:
# Make
# SUV    237
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# 6: Explore all the variables and provide observations on their distributions. (Generally, histograms, boxplots, countplots, etc. are used for univariate exploration.)

# %%
#Observation: Histogram for age:
sns.histplot(data = df, x ='Age')
plt.show()

# %%
#Observation: boxplots for Age:
sns.boxplot(data = df, x= 'Age')
plt.show()

# %% [markdown]
# #Observation: The above graph shows that the data is right skewed and the age group is between 25 to 39.
#  More than 50% stakehoilder are above 30 years of age

# %%
#Observation: countplots for age:
sns.countplot(data = df, x= 'Age')
plt.show()

# %%
#Observation: barchart for Gender:
df.value_counts('Gender').plot(kind = 'bar', edgecolor = 'Red')
plt.xlabel('-----Gender-------', fontweight = 'bold')
plt.ylabel('------Value Counts-------', fontweight = 'bold')
plt.title('Total Number of Male and female', fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'Total Number of Male and female')

# %%
#Observation for Profession and Education:
df1 = df.value_counts('Profession')
df1
# Out:
# Profession
# Salaried    896
# Business    685
# dtype: int64

# %%
df2 = df.groupby(['Profession','Marital_status']).size().unstack('Profession')
df2
# Out:
# Profession      Business  Salaried
# Marital_status
# Married              614       829
# Single                71        67

# %%
df2 = df.groupby(['Profession','Marital_status']).size().unstack('Profession').plot(kind = 'bar')
plt.xlabel('------Marital Status-------')
plt.ylabel('-------Value--------')
df2
# Out:
# <AxesSubplot:xlabel='------Marital Status-------', ylabel='-------Value--------'>

# %% [markdown]
# #Observation of Marital Status

# %%
df['Marital_status'].unique()
sns.countplot(data=df,x='Marital_status') ## Complete the code to plot 'Marital_status' column
plt.title('Total Number of Married and Single people of Organization of', fontweight = 'bold')
plt.show()

# %% [markdown]
# #Observation f partners Working

# %%
# # Check the unique values
df['Partner_working'].unique() # Complete the code to check unique values for the 'Partner_working' column  
sns.countplot(data = df, x = 'Partner_working')
# Out:
# <AxesSubplot:xlabel='Partner_working', ylabel='count'>

# %% [markdown]
# 7:  How many cars are of make Hatchback and priced above 25000. State your observations?

# %%
df1 = df[(df.Make == "Hatchback") & (df.Price >=25000)] 
df1.value_counts('Make')
# Out:
# Make
# Hatchback    491
# dtype: int64

# %% [markdown]
# #Observation: The number of Hatchback car whose price is higher than $25000 is 491.

# %% [markdown]
# 8: How many owners have bought cars that were priced higher than their salary. How many of them have taken personal loan?

# %%
# Get the number of owners who have taken cars pricing higher than their salary
df_pricing = df[df['Price'] > df['Salary']]

print('Number of owners who have purchased cars pricing higher than their salary:',df_pricing.shape[0])

# Get the number of owners who  have taken cars pricing higher than their salary and have taken personal loan.
df_personal_loan = df_pricing[df['Personal_loan'] == 'Yes']
print('Number of owners who have taken personal loan and have cars pricing higher than their salary:', df_personal_loan.shape[0])
# Out:
# Number of owners who have purchased cars pricing higher than their salary: 96
# Number of owners who have taken personal loan and have cars pricing higher than their salary: 44

# %% [markdown]
# 9: Perform a multivariate analysis to explore relationships between the important variables in the dataset. (It is a good idea to explore relations between numerical variables as well as relations between numerical and categorical variables.

# %%
# Plot the heatmap to find the correlation between numerical variables
plt.figure(figsize=(16,7))
sns.heatmap(df.corr(), annot = True, vmin = -1, vmax=1, fmt=".2f", cmap=None)
plt.show()

# %% [markdown]
# #Obeservation: This shows the relationship between two variables. The light color box shows the positive correlation
# whereas the dark color box shows the negative correlation. For example: the eqlibrium point of two variables
# (salary and age) has 0.61 value. this shows the positive correlationwhich means that the salary was increased according to the increasing age.
# The number_of_dependents columns is not hoghly co-related each other.

# %%
# pairplot to show the relationship between numerical variables set hue to Make
sns.pairplot(data = df, hue = "Make", kind = 'reg')
plt.show()

# %%
# boxplot to show relationship between two variables
plt.figure(figsize=(15,7))
sns.boxplot(data=df, x = 'Age', y='Make')  ## Complete the code to visualize the relationship between Make and Age using boxplot
plt.show()

# %% [markdown]
# #Observation: As we can see that, the sedan is mostly run by 34 to 42 age group of people.
# The SUV is mostly run by 42 to 55. age group people. This graph also shows that mostly young generation between 20 to 29 use hatchback car.

# %%
# boxplot to show relationship between two variables
plt.figure(figsize=(15,7))
sns.boxplot(data=df, x = 'Make', y='Price')  ## Complete the code to visualize the relationship between make and price using boxplot
plt.show()

# %%
# countplot to show relationship between two variables
plt.figure(figsize=(15,7))
sns.countplot(data=df, x= 'Education', hue='Make')  ## Complete the code to visualize the relationship between make and education using countplot
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %% [markdown]
# #Observation: The Hatchback car is mostly used by both post-graduated and graduated stakeholders.
# The SUV car has lowest demand by both level of people.

# %%
# countplot to show relationship between two variables
plt.figure(figsize=(15,7))
sns.countplot(data=df, x= "Profession", hue ='Make')  ## Complete the code to visualize the relationship between make and profession using countplot
plt.legend(bbox_to_anchor=(1.00, 1))
plt.title('Total number of cars used by salaried and business profession', fontweight ='bold')
plt.show()

# %%
df[df.Make=="Hatchback"].describe() # Group data w.r.t to Hatchback to build customer profiles
# Out:
#               Age  No_of_Dependents        Salary  Partner_salary  \
# count  884.000000        884.000000    884.000000      884.000000
# mean    25.874434          2.820136  54969.457014    17707.013575
# std      2.520373          0.806543  12798.737168    16250.833815
# min     22.000000          0.000000  30000.000000        0.000000
# 25%     24.000000          2.000000  47000.000000        0.000000
# 50%     26.000000          3.000000  56000.000000    25000.000000
# 75%     28.000000          3.000000  65000.000000    30000.000000
# max     30.000000          4.000000  80000.000000    50000.000000
#
#         Total_salary         Price
# count     884.000000    884.000000
# mean    72676.470588  25561.085973
# std     20078.257725   4425.257139
# min     30000.000000  18000.000000
# 25%     58000.000000  22000.000000
# 50%     73000.000000  26000.000000
# 75%     88000.000000  29000.000000
# max    120000.000000  33000.000000

# %%
# boxplot to show relationship between two variables
plt.figure(figsize=(15,7))
sns.boxplot(data=df,x='Profession', y="Price")  ## Complete the code to visualize the relationship between profession and price using boxplot
plt.show()

# %%
# pointplot to show relationship between three variables
plt.figure(figsize=(15,7))
sns.pointplot(data=df, x='No_of_Dependents',y='Price',hue="Profession", estimator ='mean')  ## Complete the code to visualize the relationship between Number of Dependents, Price and Profession using pointplot
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %% [markdown]
# #Observation: The salried employee and business man who earn more than $40,000 has one dependent.
# Both salaried and business owners has same type of coorelations betweens the variables.

# %%
# lineplot to show relationship between three variables
plt.figure(figsize=(15,7))
sns.lineplot(data=df, x='Price', y='Age',hue=df["Make"]) ## Complete the code to visualize the relationship between Age, Price and Make using pointplot
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %% [markdown]
# #Observation: The hatchback is run by below 30 years of age group whose income is around $33000.
# The SUV is run by more than 45 years of age whose income is above $50,000 approx.

# %% [markdown]
# 10:For customers who have 3 or fewer dependents, how does the average car price vary by profession ?

# %%
df_dependents = df[df.No_of_Dependents <=3] # Get the columns for no of dependents less than or equal to 3
df_profession = df_dependents.groupby(['Profession'])['Price'].mean().sort_values(ascending = False).reset_index()
df_profession
# Out:
#   Profession         Price
# 0   Salaried  37036.175711
# 1   Business  32830.220713

# %% [markdown]
# #Observation: The salaried employee whose dependets is up to 3 or less has the average price of
# car is 37036.17 approx whereas the business owner has 32830.220

# %% [markdown]
# 11: For customers who have applied a home loan and a personal loan, how does the price vary by profession?

# %%
# Filter the data for House Loans and Personal Loans
df_PL = df[df['Personal_loan'] == 'Yes']
df_HL = df[df['House_loan'] == 'Yes']

plt.figure(figsize=(15,7))
sns.boxplot(data=df, x= 'Price', hue='Profession')   ## Complete the code to visualize the relationship between Price and Profession using boxplot
plt.show()

# %% [markdown]
# #Conclusion:
# 1. Married people are drastictly high in the organization rather than single/unmarried.
# 2. Most of the people are above 30 years of age group.
# 3. Male population are higher than female populations.
# 4. There is coorelation between Price, Profession and No. of Dependents.
# 5. Post Graduate employee use hatchback cars and SUV car has high demand after graduated.
